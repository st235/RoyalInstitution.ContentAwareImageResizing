# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
def load_image(path):
  """Loads an image from hard drive using the given path.
  """
  return cv2.imread(path)

# %%
def show_image(image):
  """Shows the image.
  """
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# **Exercise:** you need to implement a method for image resizing. Method accepts an image and desired width and height, your task is to return a modified image with new sizes.
#
# **Note:** you may assume that desired width and height are smaller than the origin image sizes. If it would be easier, you can also assume that desired width and height are equal, i.e. we are making our images square.
#
# **Test:** call a method with an image and you should see a resized version of the image.

# %%
def resize_image(image, desired_width, desired_height):
  """Resizes the given image to the desired width and height.
  """
  pass

# %%
image = load_image("images/plane_4.jpeg")
show_image(image)
